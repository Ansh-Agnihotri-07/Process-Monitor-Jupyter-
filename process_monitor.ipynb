# %% [markdown]
# # 🖥️ Process Monitor — Jupyter Notebook Interface
#
# Interactive process monitoring and control powered by the C++ backend.
#
# **Features:**
# - Live process table with auto-refresh
# - Process control (kill / pause / resume / priority)
# - CPU usage visualization
# - Search and CSV export
#
# > ⚠️ **Run this notebook from the project root directory** (`Process-Monitor/`).

# %% [markdown]
# ---
# ## 📦 Setup & Imports

# %%
from gui.notebook_interface import *

# %% [markdown]
# ---
# ## 📋 One-Time Process Snapshot
# Displays a styled table of currently active processes, filtered and sorted by CPU usage.

# %%
display_processes()

# %% [markdown]
# ---
# ## 🔄 Live Monitoring
# Auto-refreshes every N seconds. **Press ⏹ (Interrupt Kernel) to stop.**

# %%
live_monitor(3)

# %% [markdown]
# ---
# ## ⚙️ Process Control
# Replace `1234` with a real PID from the table above.

# %%
# Kill a process
kill_process(1234)

# %%
# Pause a process
pause_process(1234)

# %%
# Resume a paused process
resume_process(1234)

# %%
# Change process priority (negative = higher priority)
set_priority(1234, -5)

# %% [markdown]
# ---
# ## 📊 CPU Usage Visualization
# Collects CPU samples over time and plots a trend line.

# %%
plot_cpu_usage(samples=10, interval=1.0)

# %% [markdown]
# ---
# ## 🔍 Search & Export

# %%
# Search for a process by name
search_process("chrome")

# %%
# Export current snapshot to CSV
export_to_csv("snapshot.csv")
